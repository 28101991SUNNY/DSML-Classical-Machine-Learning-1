# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#     # specific to logisitc regression :
#
#     # How do we handle the imbalanced data :
#
#     # 1 : class weights :
#         assign more weights to minority class.
#
#         n = 1000
#
#         +ve : 150
#         -ve : 850
#
#
#             850/150 = 6 :
#
#                 every class data points should be assign weight of 6
#                 to balance the logloss.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     n = 1000
#
#     class1 : 200
#         class0 : 800
#
#             800/200  =>> w1 = 4 , w0=1

# %%
df = pd.read_csv("Churn_imbalanced.csv")

# %%
df
# Out:
#       Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  ...  Intl Calls  Intl Charge  State  Area Code     Phone
# 0                128             25     265.1     197.4       244.7  ...           3         2.70     KS        415  382-4657
# 1                107             26     161.6     195.5       254.4  ...           3         3.70     OH        415  371-7191
# 2                137              0     243.4     121.2       162.6  ...           5         3.29     NJ        415  358-1921
# 3                 84              0     299.4      61.9       196.9  ...           7         1.78     OH        408  375-9999
# 4                 75              0     166.7     148.3       186.9  ...           3         2.73     OK        415  330-6626
# ...              ...            ...       ...       ...         ...  ...         ...          ...    ...        ...       ...
# ...

# %%
df["Churn"].value_counts(normalize=False)
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %%
X = df[["VMail Message","CustServ Calls","Eve Mins"]].values
y = df["Churn"].values

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kNN = KNeighborsClassifier(n_neighbors=5)

# %%
from sklearn.model_selection import cross_val_score

# %%
np.mean(cross_val_score(estimator=kNN,
               cv = 5,
                X=  X,
                y = y,
                scoring="f1"
           ))
# Out:
# 0.14562011797658037

# %%
np.mean(cross_val_score(estimator=kNN,
               cv = 5,
                X=  X,
                y = y,
                scoring="recall"
           ))
# Out:
# 0.08898195876288659

# %%
np.mean(cross_val_score(estimator=kNN,
               cv = 5,
                X=  X,
                y = y,
                scoring="precision"
           ))
# Out:
# 0.40505729564553095

# %% [markdown]
# ## SMOTE

# %% [markdown]
# Synthetic Minority Oversampling Technique (SMOTE) is a statistical technique for increasing the number of cases in your dataset in a balanced way. The component works by generating new instances from existing minority cases that you supply as input.

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(
    sampling_strategy='auto',
    random_state=None,
    k_neighbors=5,               #-----------
    n_jobs=None)

# %%
X,y = smote.fit_resample(X,y)

# %%
X.shape,y.shape
# Out:
# ((5700, 3), (5700,))

# %%
pd.Series(y).value_counts()
# Out:
# 0    2850
# 1    2850
# dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
kNN = KNeighborsClassifier(n_neighbors=5)
from sklearn.model_selection import cross_val_score
np.mean(cross_val_score(estimator=kNN,
               cv = 5,
                X=  X,
                y = y,
                scoring="f1"
           ))
# Out:
# 0.7742172481285748

# %%
from sklearn.neighbors import KNeighborsClassifier
kNN = KNeighborsClassifier(n_neighbors=5)
from sklearn.model_selection import cross_val_score
np.mean(cross_val_score(estimator=kNN,
               cv = 5,
                X=  X,
                y = y,
                scoring="recall"
           ))
# Out:
# 0.8270175438596491

# %%
from sklearn.neighbors import KNeighborsClassifier
kNN = KNeighborsClassifier(n_neighbors=5)
from sklearn.model_selection import cross_val_score
np.mean(cross_val_score(estimator=kNN,
               cv = 5,
                X=  X,
                y = y,
                scoring="precision"
           ))
# Out:
# 0.7282107886649044

# %% [markdown]
# ![image.png](attachment:image.png)
